09262246560872278,0.1437622295544948,null,0.8475607675546658,0.8397633633553296,null,0.8475607675546658,0.8919808758424115,null,0.8475607675546658,0.9203505174917845,null,0.8475607675546658,0.9116888712722613,null,0.8475607675546658,0.8863678345729975,null,0.8475607675546658,0.7494522655670773,null,0.8475607675546658,0.8279802817056486,null,0.8475607675546658,0.8752415170289657,null,0.7615507831598634,0.741623167672808,null,0.7615507831598634,0.6690128741347411,null,0.7615507831598634,0.8540038786454194,null,0.7615507831598634,0.8538157373342098,null,0.7615507831598634,0.7664662221366514,null,0.7615507831598634,0.7524979944855316,null,0.7615507831598634,0.6531679842232462,null,0.3227461792073504,0.29088519643622957,null,0.3227461792073504 ...

# %%
# add json library, for reading data

import json

# %%
# read my json data

# source: https://lombardinetworks.net/networks/the-networks/ -
# this one is "Banco Nazionale del Lavoro, Reagan, Bush, Thatcher, and the Arming of Iraq, c. 1979-1990 (4th version)"
# original image: http://www.moma.org/collection/works/82619

with open('/content/lombardi1023-banco-lavoro.json', 'r') as f:
    data = json.load(f)

# %%
# print out the length, how many nodes?
print(len(data["nodes"]))
print(len(data["links"]))

# loop through the data, check on it
for i in range(0,5):
  print(data["nodes"][i])

for i in range(0, 5):
  print(data["links"][i])
# Out:
# 342
# 428
# {'id': '9772', 'name': '[2]', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}
# {'id': '9770', 'name': '91/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}
# {'id': '9767', 'name': '89/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}
# {'id': '9764', 'name': '87/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}
# {'id': '889', 'name': 'Agha Hasan Abedi', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}
# {'source': '9770', 'target': '9772', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#YearArrow'}
# {'source': '9767', 'target': '9523', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#YearArrow'}
# {'source': '9764', 'target': '9501', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#YearArrow'}
# {'source': '889', 'target': '9150', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#InfluenceControl'}
# {'source': '9759', 'target': '9527', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#InfluenceControl'}

# %%
# take a look @ the names of the nodes

for node in data["nodes"]:
  print(node["name"])
# Out:
# [2]
# 91/1
# 89/1
# 87/1
# Agha Hasan Abedi
# Jean-Luc Lagadere
# Car and Driver
# Woman's Day
# Hachette Livres - Paris -
# Ohanes Awanes Artin
# Bruno Buhler
# AHA Turnkey Projects - Vienna -
# Mowafak Abdul Karim
# Midis Fin - Geneva -
# Mohammed Habib
# Khalaf al-Doulimi
# Montana Mgmt - Panama -
# Aladine Hussein Khamas
# Barzan al-Tikriti dir Iraqi Intelligence gov Kuwait 1990-1
# ?
# Khairallah al-Tulfah
# BAII
# 1st City Bk - Houston -
# Marshall Wiley US amb to Oman 1979-81
# Richard Murphy dep asst sec US State dept
# Richard Fairbanks US amb
# Saddam Hussein pres Iraq 1979-
# Hussein Kamel dir Min of Industry and Military Industrialization
# Fadel Kadhum
# Namir al-Naimi
# Learfan - Belfast -
# Anees M. Wadi
# Roy Ricks
# Safa al-Habobi
# TDG - London -
# Al Araby Trading - Baghdad -
# Robert Koshaba
# 1990: raided by UK customs police; charges later dismissed
# Paul Henderson
# Mark Gutteridge
# Abdul Qaddumi
# 1990: seized in US; assets forteited
# Dan Quayle vp US 1989-93
# Beurt Servaas
# Kennametal - Latrobe Fla -
# Gordon Cooper
# Roland Davis
# Richard Kendrick
# Bill Muscarella
# XYZ Options - Alabama -
# Salim Naman
# 1991: indicted in US for arms smuggling; convicted; sentenced to 4 yrs
# Sarkis Saghanalian
# Umberto D'Addosio
# Servaas Inc. - Indiana -
# Matrix Churchill US - Ohio -
# CE Kintex - Sofia -
# Stroock Stroock Lavan - NY -
# Mela Maggi
# Dale Toler
# RD&D - Va -
# 1991: murdered in Brussels by unknown assailants
# Gerald Bull
# Matrix Churchill UK - Coventry -
# Ind. Cardoen - Chile -
# Rexon Tech - NJ -
# ATI Belgique - Brussels -
# PRB - Brussels -
# SRC Composite - London -
# Paragon Holding - Panama -
# SRC Eng - London -
# Lloyd's Bank Int'l - London -
# 1991: convicted in UK; sentenced to 5 yrs
# Ali Daghir
# Euromac UK - London -
# 1989: raided by Italian police
# SRC Corp - Brussels -
# 1989: indicted in Italy; charges later dismissed
# Kassim Abbas
# TMG Eng - Baghdad -
# Euromac - Monza -
# Dow Chemical
# Arbed Steel - Lux -
# Foodline Corp
# Cecil Phillips
# Pacific Export
# Delft Insts - Neth -
# Hussein Zeineddine
# Int'l Trading Group - Paris -
# Hughes Aircraft - Calif -
# General Motors - Detroit -
# Thomsen CSF - Paris -
# Rinaldo Petrignani Italian amb to US
# William P. Rogers US sec State 1969-73
# Casper Weinberger US sec Defense 1981-7
# ASEA Brown Boveri
# George Shultz US sec State 1982-9 US sec Treas 1972-4
# proposed PC 2 plant
# Bechtel Corp - SF -
# Lummus Crest - NJ -
# MIMI
# proposed pipeline project
# Ahmed Bennani
# Patain - Paris -
# Therese Barden
# Jean Ivey
# Raytheon
# R.J. Reynolds
# Nestle S.A. - Switz -
# Hussein Juma
# UBAF - Paris -
# Intermaritime Bank - Geneva -
# Union Bank of Switz
# Azizullah Chaudhury
# Alfred Hartmann
# Franz Maissen
# Banque de Comm & Place - Geneva -
# Thes. Cont'l - Geneva -
# Mehmet Karamehmet
# Engin Bora
# Cukarona Group - Istanbul -
# Enza Parzalama
# 1991: indicted in US for bank fraud
# Yavuz Tezeller
# Enka Holdings
# Cargill Comas - Miami -
# plead guilty to export-related charges; paid $ 1 mil fine
# Robert Abboud
# Nat. Bank of Georgia - Atlanta -
# Ghaith Pharaon
# 1991: US indictments blocked by State dept
# Wafaj Dajani
# 86/2
# Fadhil al-Marsoumi
# Comet Rice - Houston -
# Iraq grain trade
# Amman Resources - Jordan -
# Gearbulk - Norway -
# Louis Dreyfus - NY -
# joint venture - Aqaba -
# Cont'l Grain - NY -
# Leigh Ann New
# 89/3
# 88/3
# 87/3
# 86/3
# Araba Holdings - Aqaba -
# Lewis Preston
# Morgan Guaranty - NY -
# Paul von Wedel
# 84/3
# 1991: indicted in US on 347 counts of bank fraud; plead guilty to 60 counts; later reneged on deal; plead guilty to 7 counts; sentenced to 3 years
# Lux bank account
# Christopher Drogoul
# 83/3
# Rogers and Wells - NY -
# Bruce Rappaport
# Commodity Credit Corp
# John Block sec 1981-6
# Robert Mosbacher sec 1989-92
# Commerce dept
# Agriculture dept
# William Casey dir CIA 1981-7 chmn SEC 1973-4
# Ronald Reagan pres US 1981-9
# George Bush vp US 1981-9 pres US 1989-93
# US Gov't
# Maxwell Rabb US amb to Italy 1981-9
# Guiseppe Vincenzino
# Lavoro Bank - Switz -
# Ademaro Lanzara
# Gianipiero Cantoni
# [1]
# 1988: convicted in US for fraud & money laundering; paid fine
# Entrade Int'l - NY -
# 85/3
# Cafa Baga
# Goran Gazivoda
# Rinato Gundagnini
# Vinko Mir
# BCCI S.A.
# Ljubljanska Banka - Yugo -
# LBS Bank - NY -
# Lawrence Eagleburger US sec of State 1992-3
# 83/2
# Carlo Salvatore
# Paolo Savona
# Roberto di Nisio
# 82/2
# Int'l Six - DC -
# Brent Scowcroft NSC 1989-93
# Henry Kissinger US sec of State 1973-7; NSC 1969-73
# Alan Stoga
# Kissinger Assocs - NY -
# Gianni Agnelli
# 1989: forced to resign post
# Nerio Nesi
# Mario Fallani
# 81/2
# Casalee - Lux -
# Count Ferdinando Borletti
# Fiat - Turin -
# 82/1
# Banca Nazionale del Lavoro - Atlanta -
# Pietro Lombardi
# Louis Messere
# Quirino di Mano
# Carlo Vecchi
# Vito Cannito
# Teodoro Monaco
# 1989: forced to resign post; 1991: indicted in Italy for fraud
# Giacomo Pedde
# Mario Girotti
# David Croffe
# Valsella Mech - Brescia -
# Amer Rashid al-Ubeidi
# 1988: raided by Italian police
# Paimpex
# Adnan Khairallah defense min
# 1993: indicted in Italy for criminal conspiracy 1995: indicted for murder
# Giulio Andreotti PM Italy 1972-3, 1976-9, 1989-91; foreign min 1983-9
# 1993: indicted in Italy for fraud & corruption 1994: convicted; sentenced to 8 yrs fled to Tunisia
# Foreign Min
# Benito Craxi PM Italy 1983-7
# 80/2
# BNL No. Amer - NY -
# Francesco Bignardi
# Gov't of Italy
# Lamberto Dini PM Italy 1995-6
# Guido Carli
# Treasury Min
# SACE
# Defense Min
# Fincant Riuniti Navali - Genua -
# Oto Melara - La Spezia -
# Paolo de Vito
# Banca Nazionale del Lavoro - Rome -
# Alberto Ferrari

# %%
# make 2nd graph object to fill

Lombardi = nx.Graph()

# %%
# add nodes from lombardi data

for node in data["nodes"]:
  Lombardi.add_node(node['id'], name=node['name'], type=node['type'])

# %%
# add edges from lombardi data

for link in data["links"]:
    # sometimes the 'amount' field is empty; handle this case
    amount = link["amount"] if link["amount"] else None
    Lombardi.add_edge(link["source"], link["target"], amount=amount, type=link["type"])

# %%
# see how many nodes + edges have been added

num_nodes = Lombardi.number_of_nodes()
num_edges = Lombardi.number_of_edges()

num_nodes, num_edges
# Out:
# (342, 427)

# %%
# make the network graph!

# generate the layout of the graph
# there are options: https://networkx.org/documentation/stable/reference/drawing.html
# most of the ones with "layout" in the name should work - try spiral_layout!
# (other layouts may need different parameters, formatting, etc.)

# general networkx (nx) documentation: https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html

pos = nx.spring_layout(Lombardi, k=0.5)
# play with k value - what happens?!

# get the node positions
node_x = []
node_y = []
for node in Lombardi.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

# create nodes on the graph, plotly
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=False,
        size=12, # marker size, circles from Scatter
        color='beige',
        line_width=1
    ),
    text=[Lombardi.nodes[node]['name'] for node in Lombardi.nodes()]  # hover text
)

# get the edge positions
edge_x = []
edge_y = []
for edge in Lombardi.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])  # Add 'None' to create the line segments
    edge_y.extend([y0, y1, None])

# create edges on the graph, plotly
edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='gray'),
    hoverinfo='none',
    mode='lines'
)


# Create the figure
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='<br>after Lombardi: <br>Banco Nazionale del Lavoro, Reagan, Bush, Thatcher, and the Arming of Iraq, c. 1979-1990 <br>(4th version). 1998',
                    titlefont_size=14,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20,l=5,r=5,t=40),
                    annotations=[ dict(
                        text="No. of nodes: {0}, No. of edges: {1}".format(num_nodes, num_edges),
                        showarrow=False,
                        xref="paper", yref="paper",
                        x=0.005, y=-0.002 ) ],
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )

# change parameters as design choices ...
fig.update_layout(plot_bgcolor='#f7f1e1', paper_bgcolor='#f7f1e1', font_family="Courier New", title_font_family="Courier New",)

# Show the figure
fig.show()

# 💥 save as HTML ... !! for future interactive use !!
fig.write_html("lombardi-network1.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e259c709-d744-45c3-9e38-ac37e349a4ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e259c709-d744-45c3-9e38-ac37e349a4ab")) {                    Plotly.newPlot(                        "e259c709-d744-45c3-9e38-ac37e349a4ab",                        [{"hoverinfo":"none","line":{"color":"gray","width":0.5},"mode":"lines","x":[0.2993094483659102,0.4690403952194041,null,0.4690403952194041,-0.4301090908517573,null,-0.9620502582435092,-0.4301090908517573,null,-0.9620502582435092,-0.7929959291517158,null,-0.33299318627571123,-0.7929959291517158,null,-0.33299318627571123,-0.9252700504126644,null,0.7102385071002835,0.4224574668959994,null,-0.7435967818890248,-0.4968081726874164,null,-0.7435967818890248,-0.15002181306415657,null,-0.6042487996896992,-0.15002181306415657,null,0.7180558100398061,-0.15002181306415657,null,-0.15002181306415657,-0.4968081726874164,null,-0.15002181306415657,-0.2813545838194858,null,-0.10128930726323908,-0.2813545838194858,null,-0.39873380012151866,-0.2813545838194858,null,0.3305691791426747,0.5833008605986485,null,0.5833008605986485,-0.026113575902250056,null,-0.2813545838194858,-0.6629060245007123,null,-0.2813545838194858,-0.49096784188326237,null,-0.2813545838194858,0.003684109217329547,null,-0.2813545838194858,-0.026113575902250056,null,-0.2813545838194858,-0.6049761914263327,null,-0.49096784188326237,-0.026113575902250056,null,-0.49096784188326237,-0.061892532263563275,null,0.003684109217329547,-0.026113575902250056,null,0.003684109217329547,-0.061892532263563275,null,-0.026113575902250056,-0.6049761914263327,null,-0.026113575902250056,0.4224574668959994,null,-0.6049761914263327,-0.061892532263563275,null,-0.061892532263563275,0.23259107852476607,null,0.3649974251303269,-0.2242505987952191,null,0.3649974251303269,0.4224574668959994,null,-0.2242505987952191,0.23259107852476607,null,0.8879743153735483,0.4224574668959994,null,0.8879743153735483,0.9689582760576889,null,0.9689582760576889,0.35107200980264724,null,0.9689582760576889,0.7506090309736541,null,0.8635031812996691,0.22180980022521782,null,0.35107200980264724,0.22180980022521782,null,-0.6816568257480944,0.22180980022521782,null,-0.6816568257480944,-0.41498561285693997,null,0.22180980022521782,-0.4857016859161058,null,0.22180980022521782,0.7506090309736541,null,-0.41498561285693997,-0.9192343484664788,null,-0.41498561285693997,-0.4857016859161058,null,-0.7404772255537827,-0.4857016859161058,null,-0.9562455859710765,-0.4857016859161058,null,-0.4857016859161058,0.1062711534540414,null,-0.9252700504126644,-0.8499059153538138,null,-0.8499059153538138,-0.4882648530874289,null,0.015173159195847856,-0.4882648530874289,null,0.015173159195847856,0.1062711534540414,null,-0.4882648530874289,0.016900557496709535,null,0.5191319015299687,0.016900557496709535,null,0.6103471130166952,-0.1591773342513354,null,-0.2787142190513323,-0.1591773342513354,null,-0.1591773342513354,0.016900557496709535,null,-0.1591773342513354,-0.48588300884763824,null,0.016900557496709535,0.22469280028091806,null,0.22469280028091806,-0.22299544816141578,null,0.22469280028091806,0.23259107852476607,null,0.4930681444224173,0.1062711534540414,null,0.4930681444224173,0.7215569740762268,null,0.4930681444224173,0.23259107852476607,null,0.7215569740762268,0.2818374871499099,null,-0.883242086678783,-0.38039318991639215,null,0.5525602397351678,-0.13812375260537116,null,-0.42407591164111663,-0.13812375260537116,null,-0.13812375260537116,-0.04820259916985667,null,0.7510912480139863,0.3364510357797439,null,-0.04820259916985667,0.3364510357797439,null,-0.04820259916985667,0.5649955122881515,null,-0.8628252160780034,-0.9356835011384984,null,0.3364510357797439,-0.18833461524532244,null,-0.935683501138 ...

# %%
# now, on your own!

# choose another Lombardi dataset: https://lombardinetworks.net/networks/the-networks/

# repeat the above steps to get a 2nd interactive network diagram!

# change some parameters:

# when you define the position (for example, pos = nx.spring_layout(Lombardi, k=0.5)) - change the layout (see documentation); change k; see what happens!
# change the colors, fonts, styling the figure (.update_layout function, https://plotly.com/python/reference/layout/)
# can you change what is the content of the hover text?

# %%
# options to expand this, if time or later:

# 3d network graph https://plotly.com/python/v3/3d-network-graph/

# do some text transformation to get the type attribute - can you incorporate it into the graph? color code the nodes?

# try d3, try cytoscape! https://d3-graph-gallery.com/graph/network_basic.html, https://cytoscape.org/

# %% [markdown]
# ⚛️ citations:
#
# - [NetworkX/Plotly tutorial](https://python.plainenglish.io/create-a-network-graph-in-python-8829e0ec6741)
# - [NetworkX Documentation](https://networkx.org/documentation/stable/index.html)
# - [Plotly Documentation](https://plotly.com/python/network-graphs/)
# - [Lombardi Networks data](https://lombardinetworks.net/networks/the-networks/)

# %% [markdown]
# ## 🪼 when you are finished! submit: 🖇️
#
# 1. Download this notebook as an `.ipynb` file (File -> Download)
# 2. Go to [this link](https://airtable.com/appJ1zoJbOnRhJYPQ/shr6LkH556ySC6uqU) and upload the file via the form.
# 3. Then you're done! In-class labs are counted as participation credit.
